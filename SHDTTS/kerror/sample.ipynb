# %%
function K(r,error)
    lre = log(r/error)
    return lre/log(lre)
end
# Out:
# K (generic function with 1 method)

# %%
it = 1/(3.1668105084779793e-6*0.001)
# Out:
# 3.1577512999999994e8

# %%
it = 1.0545718176461565e-34/(1.380649e-23*0.001)
# Out:
# 7.638232582257737e-9

# %%
K(,1e-7)
# Out:
# 6.737687915469774

# %%
using Plots

# %%
kl = zeros(12,12)
for i in 1:12,j in 1:12
    kl[i,j] = K(2^i,0.1^j)
end

# %%
heatmap(kl)

# %%
using Plots
a = randn(100000)
histogram([a*2,a])
